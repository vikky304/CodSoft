# %% [markdown]
# # MOVIE RATING PREDICTION WITH PYTHON

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV,KFold 
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error

# pd.set_option("display.max_rows",None)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Loading the Dataset

# %%
df = pd.read_csv(r"C:\Users\ADMIN\Downloads\codsoft\IMDb Movies India.csv",encoding="latin-1")
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
df.shape
# Out:
# (15509, 10)

# %% [markdown]
# #### Understanding and Pre-Processing the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %% [markdown]
# #### Data Cleaning

# %%
df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
year = df["Year"][df["Year"].isnull()==False]

# %%
year = year.apply(lambda x: int(x.strip("()")))

# %%
df.loc[year.index,"Year"] = year

# %%
duration = df["Duration"][df["Duration"].isnull()==False]

# %%
duration = duration.apply(lambda x: int(x.split(" ")[0]))

# %%
df.loc[duration.index,"Duration"] = duration

# %%
votes = df["Votes"][df["Votes"].isnull()==False]

# %%
def vote(x):
    return int(re.sub("[^0-9]", "",x))

# %%
votes = votes.apply(vote)

# %%
df.loc[votes.index,"Votes"] = votes

# %%
df["Name"] = df["Name"].apply(lambda x: np.nan if x.isspace()==True else x )

# %%
def sort(text):
    a = list(text.replace(" ","").split(","))
    a.sort(reverse=True)
    return ",".join(a)

# %%
genre = df["Genre"][df["Genre"].isnull()==False]

# %%
genre.nunique()
# Out:
# 485

# %%
genre.apply(sort).nunique()
# Out:
# 401

# %%
genre = genre.apply(sort)

# %%
df.loc[genre.index,"Genre"] = genre

# %%
df
# Out:
#                                      Name  Year Duration           Genre  \
# 0                                     NaN   NaN      NaN           Drama
# 1      #Gadhvi (He thought he was Gandhi)  2019      109           Drama
# 2                             #Homecoming  2021       90   Musical,Drama
# 3                                 #Yaaram  2019      110  Romance,Comedy
# 4                       ...And Once Again  2010      105           Drama
# ...                                   ...   ...      ...             ...
# 15504                 Zulm Ko Jala Doonga  1988      NaN          Action
# 15505                               Zulmi  1999      129    Drama,Action
# 15506                           Zulmi Raj  2005      NaN          Action
# 15507                       Zulmi Shikari  1988      NaN          Action
# 15508                        Zulm-O-Sitam  1998      130    Drama,Action
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
df[["Name","Director","Actor 1","Actor 2","Actor 3"]] = df[["Name","Director","Actor 1","Actor 2","Actor 3"]].fillna("Unknown")

# %%
mode1 = df["Genre"].mode()[0]

# %%
df["Genre"] = df["Genre"].fillna(mode1)

# %%
df["Duration"] = df["Duration"].fillna(df["Duration"].median()).astype(int)

# %%
df["Year"] = df["Year"].fillna(df["Year"].median().astype(int))

# %%
df["Votes"] = df["Votes"].fillna(df["Votes"].median().astype(int))

# %%
df.isnull().sum()
# Out:
# Name           0
# Year           0
# Duration       0
# Genre          0
# Rating      7590
# Votes          0
# Director       0
# Actor 1        0
# Actor 2        0
# Actor 3        0
# dtype: int64

# %%
for i in df.select_dtypes(exclude="O").drop("Rating",axis=1).columns:
    sc = StandardScaler()
    df[i] = sc.fit_transform(df[[i]])

# %%
for i in df.select_dtypes(include="O").columns:
    le = LabelEncoder()
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#         Name      Year  Duration  Genre  Rating     Votes  Director  Actor 1  \
# 0      13040  0.154143  0.067731     28     NaN -0.115272      1926     2250
# 1          0  1.274595 -1.043094     28     7.0 -0.120905      1548     3280
# 2          1  1.354627 -2.002443    158     NaN -0.115272      5123     3713
# 3          2  1.274595 -0.992602    227     4.4 -0.117669      3319     2917
# 4          6  0.914449 -1.245062     28     NaN -0.115272       385     3112
# ...      ...       ...       ...    ...     ...       ...       ...      ...
# 15504  13832  0.034095  0.067731      0     4.6 -0.120545      2690     2586
# 15505  13834  0.474272 -0.033253     29     4.5 -0.043359      2499      227
# 15506  13835  0.714369  0.067731      0     NaN -0.115272      2424     3609
# 15507  13836  0.034095  0.067731      0     NaN -0.115272      5549     4388
# 15508  13833  0.434256  0.017239     29     6.2 -0.119467      2195     1139
#
#        Actor 2  Actor 3
# 0          800     3108
# 1         4791      527
# 2         2866     3450
# 3         1504     4020
# 4         3462      405
# ...        ...      ...
# 15504     4299     4262
# 15505     4532      519
# 15506     4558     4481
# 15507     4558     4481
# 15508     1589      490
#
# [15509 rows x 10 columns]

# %%
pred_df = df[df["Rating"].isnull()==True].drop("Rating",axis=1).reset_index(drop=True)
pred_df.head()
# Out:
#     Name      Year  Duration  Genre     Votes  Director  Actor 1  Actor 2  \
# 0  13040  0.154143  0.067731     28 -0.115272      1926     2250      800
# 1      1  1.354627 -2.002443    158 -0.115272      5123     3713     2866
# 2      6  0.914449 -1.245062     28 -0.115272       385     3112     3462
# 3      9  0.834417 -3.567696     23 -0.115272       475     4388     4558
# 4     12  0.114127  0.067731    316 -0.115272      1741     3659     1100
#
#    Actor 3
# 0     3108
# 1     3450
# 2      405
# 3     4481
# 4     4481

# %%
new_df = df[df["Rating"].isnull()==False].reset_index(drop=True)
new_df
# Out:
#        Name      Year  Duration  Genre  Rating     Votes  Director  Actor 1  \
# 0         0  1.274595 -1.043094     28     7.0 -0.120905      1548     3280
# 1         2  1.274595 -0.992602    227     4.4 -0.117669      3319     2917
# 2         7  0.394240  0.875603    163     4.7 -0.022744      3800      895
# 3         8  0.714369  0.623143    394     7.4  0.008298      4993     1698
# 4       132  0.994482 -2.406379    362     5.6 -0.082791       305     4655
# ...     ...       ...       ...    ...     ...       ...       ...      ...
# 7914  13829  0.194159  0.067731     43     5.3 -0.105683       945     1139
# 7915  13831  0.074111 -0.235221     43     5.8 -0.116590      4416      990
# 7916  13832  0.034095  0.067731      0     4.6 -0.120545      2690     2586
# 7917  13834  0.474272 -0.033253     29     4.5 -0.043359      2499      227
# 7918  13833  0.434256  0.017239     29     6.2 -0.119467      2195     1139
#
#       Actor 2  Actor 3
# 0        4791      527
# 1        1504     4020
# 2         123     3829
# 3        2359     4763
# 4        2482     1851
# ...       ...      ...
# 7914     2440     1291
# 7915     1596     3135
# 7916     4299     4262
# 7917     4532      519
# 7918     1589      490
#
# [7919 rows x 10 columns]

# %% [markdown]
# ### Train And Test

# %%
x = new_df.drop("Rating",axis=1)
y = new_df["Rating"]

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,random_state=10,test_size=0.20)
xtrain.shape,xtest.shape,ytrain.shape,ytest.shape
# Out:
# ((6335, 9), (1584, 9), (6335,), (1584,))

# %%
col = pd.MultiIndex.from_product([["Train","Test"],["RMSE","MAPE"]])
modelscore = pd.DataFrame(columns=col)
modelscore.index.name = "Model Name"

# %%
modelscore
# Out:
# Empty DataFrame
# Columns: [(Train, RMSE), (Train, MAPE), (Test, RMSE), (Test, MAPE)]
# Index: []

# %%
def score_cal(model_df,model_name,model,x,y):
    xtrain,xtest,ytrain,ytest= train_test_split(x,y,random_state=10,test_size=0.20)
    xtrain,xtest,ytrain,ytest
    model.fit(xtrain,ytrain)
    ypred_train = model.predict(xtrain)
    ypred_test = model.predict(xtest)
    train_rmse = mean_squared_error(ytrain,ypred_train,squared=False)
    train_mape = mean_absolute_percentage_error(ytrain,ypred_train)
    test_rmse = mean_squared_error(ytest,ypred_test,squared=False)
    test_mape = mean_absolute_percentage_error(ytest,ypred_test)
    model_df.loc[model_name,:] = [train_rmse,train_mape,test_rmse,test_mape]
    return model_df

# %% [markdown]
# ### Linear Regression

# %%
lr = LinearRegression()
score_cal(modelscore,"Linear Regression",lr,x,y)
# Out:
#                       Train                Test
#                        RMSE      MAPE      RMSE      MAPE
# Model Name
# Linear Regression  1.333321  0.215261  1.337866  0.223709

# %% [markdown]
# ### Decision Tree

# %%
dt = DecisionTreeRegressor(random_state=10)
score_cal(modelscore,"Decision Tree",dt,x,y)
# Out:
#                       Train                Test
#                        RMSE      MAPE      RMSE      MAPE
# Model Name
# Linear Regression  1.333321  0.215261  1.337866  0.223709
# Decision Tree           0.0       0.0  1.632199  0.243349

# %% [markdown]
# ### Decision Tree-Tuned

# %%
params = {"max_depth":range(21),"min_samples_split":range(10)}
dt = DecisionTreeRegressor(random_state=10)
gd = GridSearchCV(dt,params,cv=5)
gd.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=10),
#              param_grid={'max_depth': range(0, 21),
#                          'min_samples_split': range(0, 10)})

# %%
gd.best_params_
# Out:
# {'max_depth': 6, 'min_samples_split': 7}

# %%
dt = DecisionTreeRegressor(max_depth=6,min_samples_split=4,random_state=10)
score_cal(modelscore,"Decision Tree-Tuned",dt,x,y)
# Out:
#                         Train                Test
#                          RMSE      MAPE      RMSE      MAPE
# Model Name
# Linear Regression    1.333321  0.215261  1.337866  0.223709
# Decision Tree             0.0       0.0  1.632199  0.243349
# Decision Tree-Tuned   1.15782  0.179757  1.224525  0.190642

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestRegressor(random_state=10)
score_cal(modelscore,"Random Forest",rf,x,y)
# Out:
#                         Train                Test
#                          RMSE      MAPE      RMSE      MAPE
# Model Name
# Linear Regression    1.333321  0.215261  1.337866  0.223709
# Decision Tree             0.0       0.0  1.632199  0.243349
# Decision Tree-Tuned   1.15782  0.179757  1.224525  0.190642
# Random Forest        0.425877  0.064823  1.129839  0.178675

# %% [markdown]
# ### Random Forest-Tuned

# %%
params = {"max_depth":range(10),"min_samples_split":range(10)}
rf = RandomForestRegressor(random_state=10)
gd = GridSearchCV(rf,params,cv=5)
gd.fit(xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=10),
#              param_grid={'max_depth': range(0, 10),
#                          'min_samples_split': range(0, 10)})

# %%
gd.best_params_
# Out:
# {'max_depth': 9, 'min_samples_split': 9}

# %%
rf = RandomForestRegressor(max_depth=9,min_samples_split=9,random_state=10)
score_cal(modelscore,"Random Forest-Tuned",rf,x,y)
# Out:
#                         Train                Test
#                          RMSE      MAPE      RMSE      MAPE
# Model Name
# Linear Regression    1.333321  0.215261  1.337866  0.223709
# Decision Tree             0.0       0.0  1.632199  0.243349
# Decision Tree-Tuned   1.15782  0.179757  1.224525  0.190642
# Random Forest        0.425877  0.064823  1.129839  0.178675
# Random Forest-Tuned  0.985633  0.154083  1.138151  0.181507

# %% [markdown]
# ### AdaBoost

# %%
adb = AdaBoostRegressor(random_state=10)
score_cal(modelscore,"AdaBoost",adb,x,y)
# Out:
#                         Train                Test
#                          RMSE      MAPE      RMSE      MAPE
# Model Name
# Linear Regression    1.333321  0.215261  1.337866  0.223709
# Decision Tree             0.0       0.0  1.632199  0.243349
# Decision Tree-Tuned   1.15782  0.179757  1.224525  0.190642
# Random Forest        0.425877  0.064823  1.129839  0.178675
# Random Forest-Tuned  0.985633  0.154083  1.138151  0.181507
# AdaBoost             1.260206  0.194232  1.265955  0.200293

# %% [markdown]
# ### Gradient Boosting

# %%
gdb = GradientBoostingRegressor(random_state=10)
score_cal(modelscore,"Gradient Boosting",gdb,x,y)
# Out:
#                         Train                Test
#                          RMSE      MAPE      RMSE      MAPE
# Model Name
# Linear Regression    1.333321  0.215261  1.337866  0.223709
# Decision Tree             0.0       0.0  1.632199  0.243349
# Decision Tree-Tuned   1.15782  0.179757  1.224525  0.190642
# Random Forest        0.425877  0.064823  1.129839  0.178675
# Random Forest-Tuned  0.985633  0.154083  1.138151  0.181507
# AdaBoost             1.260206  0.194232  1.265955  0.200293
# Gradient Boosting    1.054568  0.165228  1.118335  0.179109

# %%
modelscore.iloc[:,2]-modelscore.iloc[:,0]
# Out:
# Model Name
# Linear Regression      0.004545
# Decision Tree          1.632199
# Decision Tree-Tuned    0.066705
# Random Forest          0.703962
# Random Forest-Tuned    0.152518
# AdaBoost               0.005749
# Gradient Boosting      0.063767
# dtype: object

# %%
modelscore.iloc[:,3]-modelscore.iloc[:,1]
# Out:
# Model Name
# Linear Regression      0.008447
# Decision Tree          0.243349
# Decision Tree-Tuned    0.010884
# Random Forest          0.113852
# Random Forest-Tuned    0.027425
# AdaBoost               0.006061
# Gradient Boosting      0.013881
# dtype: object

# %% [markdown]
# #### From All the  above models Gradient Boosting has given a better result. As we shaw the minimum error in all 3 cases train,test and overall. So we conclude with using Gradient Boosting for future predictions.

# %%
pred_df
# Out:
#        Name      Year  Duration  Genre     Votes  Director  Actor 1  Actor 2  \
# 0     13040  0.154143  0.067731     28 -0.115272      1926     2250      800
# 1         1  1.354627 -2.002443    158 -0.115272      5123     3713     2866
# 2         6  0.914449 -1.245062     28 -0.115272       385     3112     3462
# 3         9  0.834417 -3.567696     23 -0.115272       475     4388     4558
# 4        12  0.114127  0.067731    316 -0.115272      1741     3659     1100
# ...     ...       ...       ...    ...       ...       ...      ...      ...
# 7585  13827  0.314208  0.067731      0 -0.115272      5362     1366     3886
# 7586  13828  0.234175  0.067731      0 -0.115272       849     2563     4706
# 7587  13830 -0.326051  0.067731      0 -0.115272      1398     3227     1547
# 7588  13835  0.714369  0.067731      0 -0.115272      2424     3609     4558
# 7589  13836  0.034095  0.067731      0 -0.115272      5549     4388     4558
#
#       Actor 3
# 0        3108
# 1        3450
# 2         405
# 3        4481
# 4        4481
# ...       ...
# 7585     1855
# 7586     4481
# 7587     4536
# 7588     4481
# 7589     4481
#
# [7590 rows x 9 columns]

# %%
rating = gdb.predict(pred_df)

# %%
pred_df["Rating"] = rating

# %%
pred_df
# Out:
#        Name      Year  Duration  Genre     Votes  Director  Actor 1  Actor 2  \
# 0     13040  0.154143  0.067731     28 -0.115272      1926     2250      800
# 1         1  1.354627 -2.002443    158 -0.115272      5123     3713     2866
# 2         6  0.914449 -1.245062     28 -0.115272       385     3112     3462
# 3         9  0.834417 -3.567696     23 -0.115272       475     4388     4558
# 4        12  0.114127  0.067731    316 -0.115272      1741     3659     1100
# ...     ...       ...       ...    ...       ...       ...      ...      ...
# 7585  13827  0.314208  0.067731      0 -0.115272      5362     1366     3886
# 7586  13828  0.234175  0.067731      0 -0.115272       849     2563     4706
# 7587  13830 -0.326051  0.067731      0 -0.115272      1398     3227     1547
# 7588  13835  0.714369  0.067731      0 -0.115272      2424     3609     4558
# 7589  13836  0.034095  0.067731      0 -0.115272      5549     4388     4558
#
#       Actor 3    Rating
# 0        3108  5.829801
# 1        3450  6.742248
# 2         405  6.193584
# 3        4481  7.408925
# 4        4481  5.225139
# ...       ...       ...
# 7585     1855  4.914657
# 7586     4481  5.533177
# 7587     4536  6.462607
# 7588     4481  5.599735
# 7589     4481  5.873640
#
# [7590 rows x 10 columns]

# %% [markdown]
# #### This is the dataset with the use of  predicted Ratings
